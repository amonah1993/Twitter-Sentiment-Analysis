# %%
# Fine Tuning pretrained BERT for Sentiment Classification using Transformers in Python
# Source: https://medium.com/nerd-for-tech/fine-tuning-pretrained-bert-for-sentiment-classification-using-transformers-in-python-931ed142e37 Retrieved in July 2022

# %%
# import libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.1-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 9.8 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 14.5 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 80.8 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 83.0 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.8.1 pyyaml-6.0 tokenizers-0.12.1 transformers-4.21.1

# %%
# loading the train dataset
train=pd.read_csv("CovidMaskTrainingDatasetPre-processed.csv")

# %%
# loading the test dataset
#test=pd.read_csv("CovidMaskPeriod2Pre-processed.csv")
test=pd.read_csv("CovidMaskPeriod1Pre-processed.csv")

# %%
test.head()

# %%
train.head()

# %%
# function to convert the sentiment score to 0,1 or 2
def getSentimentScore(score):
        if score < 0:
            return 0
        elif score == 0:
            return 1
        else:
            return 2
train['TextBlob_SentimentNumber'] = train['Sentiment'].apply(getSentimentScore)

# %%
train
# Out:
#                                                      text  Sentiment  \
# 0       @emeraldtyger @NYGovCuomo Open your home to a ...  -0.162338
# 1       Saudi Arabia records 48 coronavirus deaths, 3,...   0.136364
# 2       @venusin12th There’s a website you signup for ...   0.400000
# 3       @WarRoomPandemic @VOG_2020 Exactly! Why NO maj...   0.140625
# 4       i just wish this corona shit go away &amp; eve...  -0.200000
# ...                                                   ...        ...
# 584334  10,286,768 #Coronavirus cases as of 2020-06-29...   0.000000
# 584335  Listen to the newest episode of The Marketplac...   0.000000
# 584336  What measures are you taking to reassure custo...   0.225000
# 584337  A study found that if the nation continues to ...   0.000000
# 584338  Maharashtra Daily Report: 29 June #Maharashtra...   0.113636
#
#                                                 cleanText  \
# 0       open home covid positive elder r supposed go t...
# 1       saudi arabia records 48 coronavirus deaths 394...
# 2       there’s website signup pay subscription it’s c...
# 3       exactly major news agency ask question virus c...
# 4          wish corona shit go away everybody stop dying
# ...                                                   ...
# 584334         10286768 coronavirus cases 20200629 104001
# 584335  listen newest episode marketplace ideas podcas...
# 584336  measures taking reassure customers youre safe ...
# 584337  study found nation continues see elevated infe...
# 584338  maharashtra daily report 29 june maharashtra r...
#
#                                                 textLemma  \
# 0       open home covid positive elder r supposed go t...
# 1       saudi arabia record 48 coronavirus death 3943 ...
# 2       there s website signup pay subscription it s c...
# 3       exactly major news agency ask question virus c...
# 4          wish corona shit go away everybody stop dying
# ...                                                   ...
# 584334          10286768 coronavirus case 20200629 104001
# 584335  listen newest episode marketplace idea podcast...
# 584336  measure taking reassure customer youre safe bu...
# 584337  study found nation continues see elevated infe...
# 584338  maharashtra daily report 29 june maharashtra r...
#
#         TextBlob_SentimentNumber
# 0                              0
# 1                              2
# 2                              2
# 3                              2
# 4                              0
# ...                          ...
# 584334                         1
# 584335                         1
# 584336                         2
# 584337                         1
# 584338                         2
#
# [584339 rows x 5 columns]

# %%
# extracting features and labels 
trainText = train['textLemma'].values.tolist()
trainLabel = train['TextBlob_SentimentNumber'].values.tolist()

# %%
# split 80(training)/20(validation)
from sklearn.model_selection import train_test_split
trainText, validationText, trainLabel, validationLabel = train_test_split(trainText, trainLabel, test_size=.2,random_state=42,stratify=trainLabel)

# %%
# importing libraries
import torch
from torch.utils.data import Dataset
from transformers import DistilBertTokenizerFast,DistilBertForSequenceClassification
from transformers import Trainer,TrainingArguments

# %%
#	Loading the pretrained tokenizer  
modelTokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-cased',num_labels=3)
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/426k [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/411 [00:00<?, ?B/s]

# %%
# encode training and validation sets
trainEncoding = modelTokenizer(trainText, truncation=True, padding=True,return_tensors = 'pt')
validationEncoding = modelTokenizer(validationText, truncation=True, padding=True,return_tensors = 'pt')

# %%
#create Pytorch datasets using encodings and labels 
class SentimentDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
# creating an object of the subclasss SentimentDataset for training and validation
trainDataset = SentimentDataset(trainEncoding, trainLabel)
validationDataset = SentimentDataset(validationEncoding, validationLabel)

# %%
# creating a function for metrics calculation
from sklearn.metrics import accuracy_score, f1_score
def metricsFunction(label):
    prediction, labels = label
    prediction = np.argmax(prediction, axis=1)
    accuracyScore = accuracy_score(y_true=labels, y_pred=prediction)
    f1Score = f1_score(labels, prediction, average='weighted')

    return {"accuracy": accuracyScore,"f1_score":f1Score }

# %%
# defining training arguments 
trainingArgs = TrainingArguments(
    output_dir='./res',          # outcome directory
    evaluation_strategy="steps",
    num_train_epochs=3,              # training epochs number
    per_device_train_batch_size=32,  # training batch size per device 
    per_device_eval_batch_size=64,   # evaluation batch size 
    learning_rate=3e-5, 
    warmup_steps=500,                #  learning rate warmup steps number  
    weight_decay=0.01,               # weight decay   
    logging_dir='./logs4',            # logs directory 
    load_best_model_at_end=True,
)

# %%
# Loading the pretrained model  
model = DistilBertForSequenceClassification.from_pretrained("distilbert-base-cased",num_labels=3)
# creating the trainer object 
trainer = Trainer(
    model=model,# the Transformers model 
    args=trainingArgs, # training arguments
    train_dataset=trainDataset,# training dataset
    eval_dataset=validationDataset , # evaluation dataset
    compute_metrics=metricsFunction,
)
# start the train process
trainer.train()
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/251M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-cased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.bias', 'vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_projector.bias', 'vocab_projector.weight', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['pre_classifier.bias', 'pre_classifier.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ***** Running training *****
#   Num examples = 467471
#   Num Epochs = 3
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 43827
#     <div>
#
#       <progress value='43827' max='43827' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [43827/43827 7:58:07, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.844400</td>
#       <td>0.583558</td>
#       <td>0.778382</td>
#       <td>0.779498</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.531900</td>
#       <td>0.488240</td>
#       <td>0.828679</td>
#       <td>0.828548</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.487200</td>
#       <td>0.450466</td>
#       <td>0.844466</td>
#       <td>0.842645</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.456600</td>
#       <td>0.430501</td>
#       <td>0.854528</td>
#       <td>0.854165</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.434200</td>
#       <td>0.419031</td>
#       <td>0.853536</td>
#       <td>0.854467</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.411300</td>
#       <td>0.397757</td>
#       <td>0.865344</td>
#       <td>0.865360</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.401400</td>
#       <td>0.393736</td>
#       <td>0.867295</td>
#       <td>0.867500</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.403600</td>
#       <td>0.391761</td>
#       <td>0.867680</td>
#       <td>0.867917</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.398800</td>
#       <td>0.394442</td>
#       <td>0.869862</td>
#       <td>0.869659</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.395400</td>
#       <td>0.378990</td>
#       <td>0.874166</td>
#       <td>0.873887</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.397200</td>
#       <td>0.375019</td>
#       <td>0.873575</td>
#       <td>0.873465</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.385800</td>
#       <td>0.368359</td>
#       <td>0.874936</td>
#       <td>0.874709</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.376600</td>
#       <td>0.368079</td>
#       <td>0.874910</td>
#       <td>0.875258</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.372000</td>
#       <td>0.360524</td>
#       <td>0.877101</td>
#       <td>0.877210</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.376400</td>
#       <td>0.363399</td>
#       <td>0.877691</td>
#       <td>0.877925</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.369300</td>
#       <td>0.368781</td>
#       <td>0.876621</td>
#       <td>0.876279</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.357600</td>
#       <td>0.360016</td>
#       <td>0.878324</td>
#       <td>0.878289</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.370000</td>
#       <td>0.372129</td>
#       <td>0.874884</td>
#       <td>0.874176</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.353800</td>
#       <td>0.367465</td>
#       <td>0.878110</td>
#       <td>0.877651</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.363000</td>
#       <td>0.364401</td>
#       <td>0.881028</td>
#       <td>0.880994</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.354800</td>
#       <td>0.355593</td>
#       <td>0.880532</td>
#       <td>0.880368</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.360500</td>
#       <td>0.350927</td>
#       <td>0.881978</td>
#       <td>0.881803</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.352400</td>
#       <td>0.357607</td>
#       <td>0.882192</td>
#       <td>0.881894</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.350000</td>
#       <td>0.353279</td>
#       <td>0.882004</td>
#       <td>0.881941</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.352400</td>
#       <td>0.349441</td>
#       <td>0.884613</td>
#       <td>0.884787</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.341600</td>
#       <td>0.344803</td>
#       <td>0.883937</td>
#       <td>0.883943</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.350500</td>
#       <td>0.354209</td>
#       <td>0.882834</td>
#       <td>0.883127</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.363400</td>
#       <td>0.348259</td>
#       <td>0.885033</td>
#       <td>0.885036</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.349800</td>
#       <td>0.342959</td>
#       <td>0.885093</td>
#       <td>0.885063</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.330800</td>
#       <td>0.349785</td>
#       <td>0.886188</td>
#       <td>0.886153</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>0.325100</td>
#       <td>0.340024</td>
#       <td>0.885007</td>
#       <td>0.885294</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.312600</td>
#       <td>0.348998</td>
#       <td>0.886616</td>
#       <td>0.886786</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>0.321400</td>
#       <td>0.337818</td>
#       <td>0.887668</td>
#       <td>0.887667</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.315000</td>
#       <td>0.340677</td>
#       <td>0.886256</td>
#       <td>0.886454</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>0.314500</td>
#       <td>0.338648</td>
#       <td>0.885957</td>
#       <td>0.885751</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.320600</td>
#       <td>0.341266</td>
#       <td>0.886958</td>
#       <td>0.886942</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>0.315200</td>
#       <td>0.349968</td>
#       <td>0.886804</td>
#       <td>0.886771</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.312300</td>
#       <td>0.340608</td>
#       <td>0.887771</td>
#       <td>0.887790</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>0.310100</td>
#       <td>0.335572</td>
#       <td>0.887497</td>
#       <td>0.887570</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.312600</td>
#       <td>0.335079</td>
#       <td>0.887069</td>
#       <td>0.886954</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>0.312600</td>
#       <td>0.345045</td>
#       <td>0.886770</td>
#       <td>0.886421</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>0.313300</td>
#       <td>0.341949</td>
#       <td>0.888156</td>
#       <td>0.888023</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>0.310900</td>
#       <td>0.344683</td>
#       <td>0.888079</td>
#       <td>0.888202</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>0.301100</td>
#       <td>0.341224</td>
#       <td>0.887300</td>
#       <td>0.887449</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>0.316000</td>
#       <td>0.335917</td>
#       <td>0.888909</td>
#       <td>0.889028</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>0.313000</td>
#       <td>0.342492</td>
#       <td>0.886830</td>
#       <td>0.886666</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>0.311500</td>
#       <td>0.329766</td>
#       <td>0.889593</td>
#       <td>0.889689</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>0.312300</td>
#       <td>0.332933</td>
#       <td>0.888395</td>
#       <td>0.888483</td>
#     </tr>
#     <tr>
#       <td>24500</td>
#       <td>0.310700</td>
#       <td>0.340748</td>
#       <td>0.889200</td>
#       <td>0.889125</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>0.315700</td>
#       <td>0.334750</td>
#       <td>0.888755</td>
#       <td>0.888595</td>
#     </tr>
#     <tr>
#       <td>25500</td>
#       <td>0.309700</td>
#       <td>0.331279</td>
#       <td>0.889782</td>
#       <td>0.889847</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>0.306700</td>
#       <td>0.333242</td>
#       <td>0.889807</td>
#       <td>0.889939</td>
#     </tr>
#     <tr>
#       <td>26500</td>
#       <td>0.305400</td>
#       <td>0.330714</td>
#       <td>0.888917</td>
#       <td>0.889290</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>0.309600</td>
#       <td>0.328365</td>
#       <td>0.889474</td>
#       <td>0.889422</td>
#     </tr>
#     <tr>
#       <td>27500</td>
#       <td>0.312600</td>
#       <td>0.324512</td>
#       <td>0.890021</td>
#       <td>0.890103</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>0.306300</td>
#       <td>0.325635</td>
#       <td>0.890552</td>
#       <td>0.8905
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-500
# Configuration saved in ./res/checkpoint-500/config.json
# Model weights saved in ./res/checkpoint-500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-1000
# Configuration saved in ./res/checkpoint-1000/config.json
# Model weights saved in ./res/checkpoint-1000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-1500
# Configuration saved in ./res/checkpoint-1500/config.json
# Model weights saved in ./res/checkpoint-1500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-2000
# Configuration saved in ./res/checkpoint-2000/config.json
# Model weights saved in ./res/checkpoint-2000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-2500
# Configuration saved in ./res/checkpoint-2500/config.json
# Model weights saved in ./res/checkpoint-2500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-3000
# Configuration saved in ./res/checkpoint-3000/config.json
# Model weights saved in ./res/checkpoint-3000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-3500
# Configuration saved in ./res/checkpoint-3500/config.json
# Model weights saved in ./res/checkpoint-3500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-4000
# Configuration saved in ./res/checkpoint-4000/config.json
# Model weights saved in ./res/checkpoint-4000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-4500
# Configuration saved in ./res/checkpoint-4500/config.json
# Model weights saved in ./res/checkpoint-4500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-5000
# Configuration saved in ./res/checkpoint-5000/config.json
# Model weights saved in ./res/checkpoint-5000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-5500
# Configuration saved in ./res/checkpoint-5500/config.json
# Model weights saved in ./res/checkpoint-5500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-6000
# Configuration saved in ./res/checkpoint-6000/config.json
# Model weights saved in ./res/checkpoint-6000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-6500
# Configuration saved in ./res/checkpoint-6500/config.json
# Model weights saved in ./res/checkpoint-6500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-7000
# Configuration saved in ./res/checkpoint-7000/config.json
# Model weights saved in ./res/checkpoint-7000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-7500
# Configuration saved in ./res/checkpoint-7500/config.json
# Model weights saved in ./res/checkpoint-7500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-8000
# Configuration saved in ./res/checkpoint-8000/config.json
# Model weights saved in ./res/checkpoint-8000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-8500
# Configuration saved in ./res/checkpoint-8500/config.json
# Model weights saved in ./res/checkpoint-8500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-9000
# Configuration saved in ./res/checkpoint-9000/config.json
# Model weights saved in ./res/checkpoint-9000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-9500
# Configuration saved in ./res/checkpoint-9500/config.json
# Model weights saved in ./res/checkpoint-9500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-10000
# Configuration saved in ./res/checkpoint-10000/config.json
# Model weights saved in ./res/checkpoint-10000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-10500
# Configuration saved in ./res/checkpoint-10500/config.json
# Model weights saved in ./res/checkpoint-10500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-11000
# Configuration saved in ./res/checkpoint-11000/config.json
# Model weights saved in ./res/checkpoint-11000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-11500
# Configuration saved in ./res/checkpoint-11500/config.json
# Model weights saved in ./res/checkpoint-11500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-12000
# Configuration saved in ./res/checkpoint-12000/config.json
# Model weights saved in ./res/checkpoint-12000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-12500
# Configuration saved in ./res/checkpoint-12500/config.json
# Model weights saved in ./res/checkpoint-12500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-13000
# Configuration saved in ./res/checkpoint-13000/config.json
# Model weights saved in ./res/checkpoint-13000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-13500
# Configuration saved in ./res/checkpoint-13500/config.json
# Model weights saved in ./res/checkpoint-13500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-14000
# Configuration saved in ./res/checkpoint-14000/config.json
# Model weights saved in ./res/checkpoint-14000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-14500
# Configuration saved in ./res/checkpoint-14500/config.json
# Model weights saved in ./res/checkpoint-14500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-15000
# Configuration saved in ./res/checkpoint-15000/config.json
# Model weights saved in ./res/checkpoint-15000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-15500
# Configuration saved in ./res/checkpoint-15500/config.json
# Model weights saved in ./res/checkpoint-15500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-16000
# Configuration saved in ./res/checkpoint-16000/config.json
# Model weights saved in ./res/checkpoint-16000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-16500
# Configuration saved in ./res/checkpoint-16500/config.json
# Model weights saved in ./res/checkpoint-16500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-17000
# Configuration saved in ./res/checkpoint-17000/config.json
# Model weights saved in ./res/checkpoint-17000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-17500
# Configuration saved in ./res/checkpoint-17500/config.json
# Model weights saved in ./res/checkpoint-17500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-18000
# Configuration saved in ./res/checkpoint-18000/config.json
# Model weights saved in ./res/checkpoint-18000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-18500
# Configuration saved in ./res/checkpoint-18500/config.json
# Model weights saved in ./res/checkpoint-18500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-19000
# Configuration saved in ./res/checkpoint-19000/config.json
# Model weights saved in ./res/checkpoint-19000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-19500
# Configuration saved in ./res/checkpoint-19500/config.json
# Model weights saved in ./res/checkpoint-19500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-20000
# Configuration saved in ./res/checkpoint-20000/config.json
# Model weights saved in ./res/checkpoint-20000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-20500
# Configuration saved in ./res/checkpoint-20500/config.json
# Model weights saved in ./res/checkpoint-20500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-21000
# Configuration saved in ./res/checkpoint-21000/config.json
# Model weights saved in ./res/checkpoint-21000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-21500
# Configuration saved in ./res/checkpoint-21500/config.json
# Model weights saved in ./res/checkpoint-21500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-22000
# Configuration saved in ./res/checkpoint-22000/config.json
# Model weights saved in ./res/checkpoint-22000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-22500
# Configuration saved in ./res/checkpoint-22500/config.json
# Model weights saved in ./res/checkpoint-22500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-23000
# Configuration saved in ./res/checkpoint-23000/config.json
# Model weights saved in ./res/checkpoint-23000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-23500
# Configuration saved in ./res/checkpoint-23500/config.json
# Model weights saved in ./res/checkpoint-23500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-24000
# Configuration saved in ./res/checkpoint-24000/config.json
# Model weights saved in ./res/checkpoint-24000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-24500
# Configuration saved in ./res/checkpoint-24500/config.json
# Model weights saved in ./res/checkpoint-24500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-25000
# Configuration saved in ./res/checkpoint-25000/config.json
# Model weights saved in ./res/checkpoint-25000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-25500
# Configuration saved in ./res/checkpoint-25500/config.json
# Model weights saved in ./res/checkpoint-25500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-26000
# Configuration saved in ./res/checkpoint-26000/config.json
# Model weights saved in ./res/checkpoint-26000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-26500
# Configuration saved in ./res/checkpoint-26500/config.json
# Model weights saved in ./res/checkpoint-26500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-27000
# Configuration saved in ./res/checkpoint-27000/config.json
# Model weights saved in ./res/checkpoint-27000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-27500
# Configuration saved in ./res/checkpoint-27500/config.json
# Model weights saved in ./res/checkpoint-27500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-28000
# Configuration saved in ./res/checkpoint-28000/config.json
# Model weights saved in ./res/checkpoint-28000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-28500
# Configuration saved in ./res/checkpoint-28500/config.json
# Model weights saved in ./res/checkpoint-28500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-29000
# Configuration saved in ./res/checkpoint-29000/config.json
# Model weights saved in ./res/checkpoint-29000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-29500
# Configuration saved in ./res/checkpoint-29500/config.json
# Model weights saved in ./res/checkpoint-29500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-30000
# Configuration saved in ./res/checkpoint-30000/config.json
# Model weights saved in ./res/checkpoint-30000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-30500
# Configuration saved in ./res/checkpoint-30500/config.json
# Model weights saved in ./res/checkpoint-30500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-31000
# Configuration saved in ./res/checkpoint-31000/config.json
# Model weights saved in ./res/checkpoint-31000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-31500
# Configuration saved in ./res/checkpoint-31500/config.json
# Model weights saved in ./res/checkpoint-31500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-32000
# Configuration saved in ./res/checkpoint-32000/config.json
# Model weights saved in ./res/checkpoint-32000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-32500
# Configuration saved in ./res/checkpoint-32500/config.json
# Model weights saved in ./res/checkpoint-32500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-33000
# Configuration saved in ./res/checkpoint-33000/config.json
# Model weights saved in ./res/checkpoint-33000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-33500
# Configuration saved in ./res/checkpoint-33500/config.json
# Model weights saved in ./res/checkpoint-33500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-34000
# Configuration saved in ./res/checkpoint-34000/config.json
# Model weights saved in ./res/checkpoint-34000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-34500
# Configuration saved in ./res/checkpoint-34500/config.json
# Model weights saved in ./res/checkpoint-34500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-35000
# Configuration saved in ./res/checkpoint-35000/config.json
# Model weights saved in ./res/checkpoint-35000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-35500
# Configuration saved in ./res/checkpoint-35500/config.json
# Model weights saved in ./res/checkpoint-35500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-36000
# Configuration saved in ./res/checkpoint-36000/config.json
# Model weights saved in ./res/checkpoint-36000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-36500
# Configuration saved in ./res/checkpoint-36500/config.json
# Model weights saved in ./res/checkpoint-36500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-37000
# Configuration saved in ./res/checkpoint-37000/config.json
# Model weights saved in ./res/checkpoint-37000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-37500
# Configuration saved in ./res/checkpoint-37500/config.json
# Model weights saved in ./res/checkpoint-37500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-38000
# Configuration saved in ./res/checkpoint-38000/config.json
# Model weights saved in ./res/checkpoint-38000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-38500
# Configuration saved in ./res/checkpoint-38500/config.json
# Model weights saved in ./res/checkpoint-38500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-39000
# Configuration saved in ./res/checkpoint-39000/config.json
# Model weights saved in ./res/checkpoint-39000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-39500
# Configuration saved in ./res/checkpoint-39500/config.json
# Model weights saved in ./res/checkpoint-39500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-40000
# Configuration saved in ./res/checkpoint-40000/config.json
# Model weights saved in ./res/checkpoint-40000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-40500
# Configuration saved in ./res/checkpoint-40500/config.json
# Model weights saved in ./res/checkpoint-40500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-41000
# Configuration saved in ./res/checkpoint-41000/config.json
# Model weights saved in ./res/checkpoint-41000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-41500
# Configuration saved in ./res/checkpoint-41500/config.json
# Model weights saved in ./res/checkpoint-41500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-42000
# Configuration saved in ./res/checkpoint-42000/config.json
# Model weights saved in ./res/checkpoint-42000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-42500
# Configuration saved in ./res/checkpoint-42500/config.json
# Model weights saved in ./res/checkpoint-42500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-43000
# Configuration saved in ./res/checkpoint-43000/config.json
# Model weights saved in ./res/checkpoint-43000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
# Saving model checkpoint to ./res/checkpoint-43500
# Configuration saved in ./res/checkpoint-43500/config.json
# Model weights saved in ./res/checkpoint-43500/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./res/checkpoint-27500 (score: 0.32451164722442627).
# TrainOutput(global_step=43827, training_loss=0.32427284250645205, metrics={'train_runtime': 28689.8478, 'train_samples_per_second': 48.882, 'train_steps_per_second': 1.528, 'total_flos': 4.644432874173773e+16, 'train_loss': 0.32427284250645205, 'epoch': 3.0})

# %%
# evaluate the model using the validation dataset
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 116868
#   Batch size = 64
#     <div>
#
#       <progress value='1827' max='1827' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1827/1827 03:49]
#     </div>
# {'eval_loss': 0.32451164722442627,
#  'eval_accuracy': 0.8900212205222987,
#  'eval_f1_score': 0.8901032899650411,
#  'eval_runtime': 230.0055,
#  'eval_samples_per_second': 508.11,
#  'eval_steps_per_second': 7.943,
#  'epoch': 3.0}

# %%
# create a new column in test called Sentiment and initilaize it with zero
test['Sentiment'] = 0 
# extract the features and labels 
testText = test['textLemma'].values.tolist() 
testLabel = test['Sentiment'].values.tolist() 
# encode the testing set
testEncoding = modelTokenizer(testText, truncation=True, padding=True,return_tensors = 'pt')
# creating an object of the subclasss SentimentDataset for testing set 
testDataset = SentimentDataset(testEncoding, testLabel)
# predict the sentiments 
preds = trainer.predict(test_dataset=testDataset)
# Out:
# ***** Running Prediction *****
#   Num examples = 366266
#   Batch size = 64

# %%
# probabilities of test sentiments prediction 
probabilities = torch.from_numpy(preds[0]).softmax(1)
# convert to numpy array
predictions = probabilities.numpy()

# %%
predictions
# Out:
# array([[0.13382936, 0.61746526, 0.24870543],
#        [0.9312634 , 0.00341962, 0.06531709],
#        [0.05926002, 0.01155891, 0.9291811 ],
#        ...,
#        [0.02905289, 0.9338011 , 0.03714601],
#        [0.01483336, 0.23316966, 0.75199693],
#        [0.00454289, 0.00394607, 0.99151105]], dtype=float32)

# %%
# the numpy array probabilities are converted into a data frame 
probabilitiesArray = pd.DataFrame(predictions,columns=['Negative','Neutral','Positive'])
probabilitiesArray.head()
# Out:
#    Negative   Neutral  Positive
# 0  0.133829  0.617465  0.248705
# 1  0.931263  0.003420  0.065317
# 2  0.059260  0.011559  0.929181
# 3  0.034537  0.003225  0.962238
# 4  0.059267  0.853316  0.087417

# %%
# function to generate the sentiment label
def labelFunction(x):
  if x == 0:
    return 'Negative'
  elif x == 1:
    return 'Neutral'
  else:
    return 'Positive'
# adding the sentiment labels into the sentiment column in test dataset
resultSentiments = np.argmax(predictions,axis=1)
test['Sentiment'] = resultSentiments
test['Sentiment'] = test['Sentiment'].map(labelFunction)
test.head()
# Out:
#                     id                                               text  \
# 0  1277300891335491584  #Weakness \n"While Trump almost invariably esc...
# 1  1277300871928266752  @JoeBiden I don't think I have ever been so di...
# 2  1277300855763582976  ALSOO the mask mostly prevents people from spr...
# 3  1277300855134273536  @bga1228 @Im_YoPusha @Lisaaa40 @Bethenny I’m n...
# 4  1277300821839970309  @timmyvoe @piersmorgan Have experience in deal...
#
#   created_at                                          cleanText  \
# 0        Jun  weakness trump almost invariably eschews masks...
# 1        Jun  dont think ever disappointed presidential cand...
# 2        Jun  alsoo mask mostly prevents people spreading pr...
# 3        Jun  i’m saying exactly i’m saying people caring se...
# 4        Jun  experience dealing virus outbreaks mask wearin...
#
#                                            textLemma Sentiment
# 0  weakness trump almost invariably eschews mask ...   Neutral
# 1  dont think ever disappointed presidential cand...  Negative
# 2  alsoo mask mostly prevents people spreading pr...  Positive
# 3  i m saying exactly i m saying people caring se...  Positive
# 4  experience dealing virus outbreak mask wearing...   Neutral

# %%
# concatenation of test and probabilitiesArray datasets 
test = pd.concat([test, probabilitiesArray], axis=1, join='inner')

# %%
# calculate the maximum value between the 3 sentiments 
test["SentimentScoreMax"]=test[["Negative", "Neutral","Positive"]].max(axis=1)

# %%
# generate the sentiments level (intensity) and add in a new column called SentimentLevel
def getScore(test):
        if test['Sentiment']=='Negative' and test['SentimentScoreMax']>0.5 :
            return 'High Negative'
        elif test['Sentiment']=='Negative' and test['SentimentScoreMax']<0.5:
            return 'Low Negative'
        elif test['Sentiment']=='Neutral' and test['SentimentScoreMax']<0.5:
            return 'Low Neutral'
        elif test['Sentiment']=='Neutral' and test['SentimentScoreMax']>0.5 :
            return 'High Neutral'
        elif test['Sentiment']=='Positive' and test['SentimentScoreMax']<0.5:
            return 'Low Positive'
        elif test['Sentiment']=='Positive' and test['SentimentScoreMax']>0.5 :
            return 'High Positive'
        else:
            return np.NaN
        
test['SentimentLevel']=test.apply(lambda test : getScore(test), axis=1)

# %%
test.head()
# Out:
#                     id                                               text  \
# 0  1277300891335491584  #Weakness \n"While Trump almost invariably esc...
# 1  1277300871928266752  @JoeBiden I don't think I have ever been so di...
# 2  1277300855763582976  ALSOO the mask mostly prevents people from spr...
# 3  1277300855134273536  @bga1228 @Im_YoPusha @Lisaaa40 @Bethenny I’m n...
# 4  1277300821839970309  @timmyvoe @piersmorgan Have experience in deal...
#
#   created_at                                          cleanText  \
# 0        Jun  weakness trump almost invariably eschews masks...
# 1        Jun  dont think ever disappointed presidential cand...
# 2        Jun  alsoo mask mostly prevents people spreading pr...
# 3        Jun  i’m saying exactly i’m saying people caring se...
# 4        Jun  experience dealing virus outbreaks mask wearin...
#
#                                            textLemma Sentiment  Negative  \
# 0  weakness trump almost invariably eschews mask ...   Neutral  0.133829
# 1  dont think ever disappointed presidential cand...  Negative  0.931263
# 2  alsoo mask mostly prevents people spreading pr...  Positive  0.059260
# 3  i m saying exactly i m saying people caring se...  Positive  0.034537
# 4  experience dealing virus outbreak mask wearing...   Neutral  0.059267
#
#     Neutral  Positive  SentimentScoreMax SentimentLevel
# 0  0.617465  0.248705           0.617465   High Neutral
# 1  0.003420  0.065317           0.931263  High Negative
# 2  0.011559  0.929181           0.929181  High Positive
# 3  0.003225  0.962238           0.962238  High Positive
# 4  0.853316  0.087417           0.853316   High Neutral

# %%
# saving the testing dataset with predicted sentiments in a CSV file 
test.to_csv('CovidMaskPeriod1Predicted.csv', mode='w', encoding='utf-8', index=False, line_terminator='\n')
#test.to_csv('CovidMaskPeriod2Predicted.csv', mode='w', encoding='utf-8', index=False, line_terminator='\n')

# %%
from google.colab import files

files.download('CovidMaskPeriod1PredictedBERTSentiments.csv')
#files.download('CovidMaskPeriod2PredictedBERTSentiments.csv')
